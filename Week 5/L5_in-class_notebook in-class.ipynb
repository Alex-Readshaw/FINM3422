# %% [markdown]
# # FINM3422 – Lecture 5 In‑Class Notebook (Foundations)
# Use this during the lecture. Cells marked **TODO (lecture)** are completed live in class.

# %%
# %pip install --upgrade pip
# %pip install pandas
# %pip install matplotlib
# Out:
# Requirement already satisfied: pip in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (26.0.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/alexreadshaw/Library/Python/3.13/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /Users/alexreadshaw/Library/Python/3.13/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (2.2.3)
# Requirement already satisfied: packaging>=20.0 in /Users/alexreadshaw/Library/Python/3.13/lib/python/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/alexreadshaw/Library/Python/3.13/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/alexreadshaw/Library/Python/3.13/lib/python/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# 0) Sanity check: Python, pandas, matplotlib
print('Hello FINM3422 👋')
import sys, pandas as pd, matplotlib.pyplot as plt
sys.version.split()[0]
# Out:
# Hello FINM3422 👋
# '3.13.2'

# %% [markdown]
# ## 1) Load data (prices, monthly)
# We keep a tiny CSV in `data/prices_monthly.csv` with a `Date` column and a few asset columns.

# %%
# TODO (lecture): Run the following code : Create a DataFrame of stock prices for two stocks A and B:
prices = pd.DataFrame({'A':[100,101,103],'B':[100,99,100]}, index=pd.to_datetime(['2020-01-31','2020-02-29','2020-03-31']))
prices.head()
# Out:
#               A    B
# 2020-01-31  100  100
# 2020-02-29  101   99
# 2020-03-31  103  100

# %%
# TODO (lecture): read the CSV so that Date becomes the index and is parsed as datetime
import pandas as pd
prices = pd.read_csv('prices_monthly.csv', parse_dates=['Date'], index_col='Date')
prices.head()
# Out:
#             AUS_Equity  US_Equity  Global_Bond    Gold    Cash
# Date
# 2019-01-31      100.29      92.18       101.19   98.01  100.22
# 2019-02-28      105.68      90.72       102.47  103.23  100.15
# 2019-03-31      105.25      88.95       103.84  101.93  100.28
# 2019-04-30       98.98      88.62       104.50   88.89  100.26
# 2019-05-31      102.18      91.05       105.86   95.35  100.16

# %% [markdown]
# ## 2) Inspect quickly
# Use `.info()`, `.head()`, and `.describe()` to build trust in the table before modelling.

# %%
prices.info()
display(prices.head())
display(prices.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 72 entries, 2019-01-31 to 2024-12-31
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   AUS_Equity   72 non-null     float64
#  1   US_Equity    72 non-null     float64
#  2   Global_Bond  72 non-null     float64
#  3   Gold         72 non-null     float64
#  4   Cash         72 non-null     float64
# dtypes: float64(5)
# memory usage: 3.4 KB
#             AUS_Equity  US_Equity  Global_Bond    Gold    Cash
# Date
# 2019-01-31      100.29      92.18       101.19   98.01  100.22
# 2019-02-28      105.68      90.72       102.47  103.23  100.15
# 2019-03-31      105.25      88.95       103.84  101.93  100.28
# 2019-04-30       98.98      88.62       104.50   88.89  100.26
# 2019-05-31      102.18      91.05       105.86   95.35  100.16
#        AUS_Equity  US_Equity  Global_Bond        Gold        Cash
# count   72.000000  72.000000    72.000000   72.000000   72.000000
# mean   132.818611  80.135139   117.706806   89.711389  101.471944
# std     20.937049   9.458293     7.020437   14.328678    0.843959
# min     96.600000  62.080000   101.190000   56.600000  100.150000
# 25%    111.755000  72.040000   112.477500   81.325000  100.630000
# 50%    142.355000  78.865000   119.800000   92.415000  101.480000
# 75%    149.872500  88.605000   121.850000   97.942500  102.247500
# max    166.180000  99.160000   131.090000  127.490000  102.840000

# %% [markdown]
# ## 3) Compute simple returns
# We want fractional monthly returns from prices.

# %%
# TODO (lecture): fill in pct_change to compute returns
# returns = prices.____().dropna()
returns = prices.pct_change().dropna()

# %% [markdown]
# ## 4) Ensure monthly labels
# Label the index monthly (no aggregation).

# %%
# TODO (lecture): use asfreq to set a monthly frequency label
# returns = returns.____('ME')
returns = returns.asfreq('ME')
returns.index.freq

# %% [markdown]
# ## 5) Wealth index & one plot
# From returns to an indexed wealth curve (start = 1.0).

# %%
# TODO (lecture): complete the one-liner for wealth index
import matplotlib.pyplot as plt
wealth = (1 + returns).asfreq('ME').cumprod()
ax = wealth.plot(title='Wealth index (start=1.0)')
ax.set_xlabel('Date'); ax.set_ylabel('Index'); plt.show()

# %% [markdown]
# ## 6) Stretch: handle missing values (choose & document)
# Decide whether to `ffill`, `bfill`, or `dropna`, and *state why*.

# %%
# OPTIONAL TODO (lecture/tutorial): experiment with missing-data handling
returns_clean = returns.dropna()
returns_clean.head()
# Out:
#             AUS_Equity  US_Equity  Global_Bond      Gold      Cash
# Date
# 2019-02-28    0.053744  -0.015839     0.012649  0.053260 -0.000698
# 2019-03-31   -0.004069  -0.019511     0.013370 -0.012593  0.001298
# 2019-04-30   -0.059572  -0.003710     0.006356 -0.127931 -0.000199
# 2019-05-31    0.032330   0.027420     0.013014  0.072674 -0.000997
# 2019-06-30    0.016735   0.006590    -0.001889 -0.030309  0.001098

# %% [markdown]
# ## 7) Save figure (optional)
# Saving outputs makes your work reproducible.

# %%
# OPTIONAL: save plot
import os
os.makedirs('outputs', exist_ok=True)
ax = wealth.plot(title='Wealth index (saved)')
plt.savefig('outputs/wealth_index.png', dpi=150); plt.close()
'Saved to outputs/wealth_index.png'
# Out:
# 'Saved to outputs/wealth_index.png'
